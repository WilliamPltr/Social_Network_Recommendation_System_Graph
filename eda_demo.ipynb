# %% [markdown]
# # EDA Demo Notebook
#
# This notebook provides basic exploratory data analysis (EDA) on the SNAP GitHub graph
# and the LinkedIn job listings used in the project.

# %%
from pathlib import Path

import pandas as pd

DATA_ROOT = Path('.').resolve()

edges = pd.read_csv(DATA_ROOT / 'musae_git_edges.csv', header=None, names=['src', 'dst'])
print('Edges:', edges.shape)

targets = pd.read_csv(DATA_ROOT / 'musae_git_target.csv')
print('Targets:', targets.shape)
