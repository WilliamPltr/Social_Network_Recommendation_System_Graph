# %% [markdown]
# # EDA Demo Notebook
#
# This notebook provides basic exploratory data analysis (EDA) on the SNAP GitHub graph
# and the LinkedIn job listings used in the project.

# %%
import pandas as pd

edges = pd.read_csv('musae_git_edges.csv', header=None, names=['src', 'dst'])
print('Edges:', edges.shape)

targets = pd.read_csv('musae_git_target.csv')
print('Targets:', targets.shape)
# Out:
# Edges: (289004, 2)
# Targets: (37700, 3)
# /var/folders/_f/0ygxmxlx0bnbs9bc_k31wlmr0000gn/T/ipykernel_49407/3651035534.py:3: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   edges = pd.read_csv('musae_git_edges.csv', header=None, names=['src', 'dst'])
